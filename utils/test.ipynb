# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("../data/combined.csv")

# %%
sample1 = df.sample(n = 10)

# %%
df2 = pd.read_csv("../data/spotify_songs.csv")
sample2 = df2.sample(n = 10)

# %%
sample1
# Out:
#                                                       song  \
# 1599161  Pièces de clavecin, Book 2, 6th Ordre in B-Fla...
# 5335886                                      Beautiful Day
# 1124221                            The Massacre of Glencoe
# 3051492                                               Push
# 4616675                                           Over You
# 2100799       Can't Get Enough of Your Love - C+C Base Dub
# 6805504                                 LIFELESS DISSTRACK
# 700397                   Harlequin (Arlequim Desconhecido)
# 5042576                                        Otwórz oczy
# 2664198                                  Journey to Ixtlan
#
#                                                     artist
# 1599161               ['François Couperin', 'Xavier Jara']
# 5335886                                              Inger
# 1124221  ['Anonymous', 'Meredith Hall', 'Betsy MacMilla...
# 3051492                                             Pepper
# ...

# %%
sample2.rename(columns = {'track_name': 'song', 'track_artist': 'artist'}, inplace = True)
sample2
# Out:
#                      track_id  \
# 29288  2h97U98Z3AgF7RjKtyW1c2
# 26680  3qE2w43yCbFDwkeXQsDAu6
# 16522  7q6kaOmPSc5cXRPp82pCs8
# 20183  4QrPdtlh4SkQu0tcZeNVGK
# 7900   3Osd3Yf8K73aj4ySn6LrvK
# 25570  300DUx4tdtCdGEUXR032jA
# 27023  4igAu9QaF0KdGuTBK2yuKE
# 10195  61u7CLDwOodpdENZTTsxUd
# 5211   4jmADw2rRriDjzSruTySZ7
# 18814  684EjRHwNsZQ9hCQxL4NYL
#
#                                                     song         artist  \
# 29288                                        Masterpiece       Jessie J
# 26680                                       Never Change       Choklate
# 16522                                         Sunbathing          Dye O
# 20183                              Arcade - Original Mix     RoulnDoors
# 7900                               No Church In The Wild          JAY-Z
# 25570                                       Palace/Curse   The Internet
# 27023                                    Falling For You    Anaesthesia
# ...

# %%
pd.merge(sample1, sample2, how = 'outer', on = ['song', 'artist'])
# Out:
#                                                  song  \
# 0                                               7 5 0
# 1                               Arcade - Original Mix
# 2                                       Beautiful Day
# 3        Can't Get Enough of Your Love - C+C Base Dub
# 4   El Favor (with Nicky Jam & Sech, feat. Farruko...
# 5                                     Falling For You
# 6                   Harlequin (Arlequim Desconhecido)
# 7                                   Journey to Ixtlan
# 8                                  LIFELESS DISSTRACK
# 9                                         Masterpiece
# 10                                       Never Change
# 11                              No Church In The Wild
# 12                                        Otwórz oczy
# 13                                           Over You
# 14                                       Palace/Curse
# 15  Pièces de clavecin, Book 2, 6th Ordre in B-Fla...
# ...
