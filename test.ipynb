# %%
import os 
import pandas as pd 
import numpy as np
import spotipy
from spotipy.oauth2 import SpotifyOAuth

# %%
df = pd.read_csv('filtered_combined.csv')

# %%
sample = df[df['artist'] == 'Justin Bieber']
sample
# Out:
#                                                       song         artist  \
# 14706                            1 2 3 4 5 Spend the Night  Justin Bieber
# 42964                                               2 Much  Justin Bieber
# 143088                                     A Song For Mama  Justin Bieber
# 148985                             A Very Bieber Christmas  Justin Bieber
# 205621                                       Afraid To Say  Justin Bieber
# 229923                                        Ain’t Afraid  Justin Bieber
# 253001                                       All Around Me  Justin Bieber
# 253186                                All Around the World  Justin Bieber
# 253340                                             All Bad  Justin Bieber
# 261084                     All I Want For Christmas Is You  Justin Bieber
# 262393                                      All In It Demo  Justin Bieber
# 269444                                       All She Wrote  Justin Bieber
# ...
